# %%
from IPython.display import display
import PIL.Image
import selenium.webdriver

# %%
driver = selenium.webdriver.Safari()
driver.get("http://127.0.0.1:4000")

# %%
import io
stream = io.BytesIO(driver.get_screenshot_as_png())
display(PIL.Image.open(stream))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=800x520 at 0x7FBD10DDCF40>

# %%
driver.close()
